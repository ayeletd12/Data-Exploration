# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sales = pd.read_csv('D:/sales_data_sample.csv', encoding = "ISO-8859-1",
                    parse_dates=['ORDERDATE'])
sales.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0 2003-02-24  Shipped       1         2     2003  ...
# 1 2003-05-07  Shipped       2         5     2003  ...
# 2 2003-07-01  Shipped       3         7     2003  ...
# 3 2003-08-25  Shipped       3         8     2003  ...
# 4 2003-10-10  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
sales.shape
# Out:
# (2823, 25)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   datetime64[ns]
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
sales.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %%
#numeric visualization
sales['PRICEEACH'].plot(kind='box')

# %%
ax = sales['SALES'].plot(kind='kde')
ax.axvline(sales['SALES'].mean(), color='red')
ax.axvline(sales['SALES'].median(), color='blue')

# %%
sales['QUANTITYORDERED'].plot(kind='hist')

# %%
sales['PRICEEACH'].plot(kind='hist')

# %%
sales['MSRP'].plot(kind='hist')

# %%
sales['STATUS'].value_counts().plot(kind='bar')

# %%
sales['CITY'].value_counts().plot(kind='bar')

# %%
sales['STATE'].value_counts().plot(kind='bar')

# %%
sales['COUNTRY'].value_counts().plot(kind='pie',figsize=(10, 8))

# %%
sales['CITY'].value_counts().plot(kind='pie',figsize=(10, 8))

# %%
sales['TERRITORY'].value_counts().plot(kind='pie',figsize=(10, 8))

# %%
sales['CONTACTLASTNAME'].value_counts().plot(kind='pie',figsize=(15, 12))

# %%
sales['PRODUCTCODE'].value_counts().plot(kind='bar')

# %%
sales['PRODUCTLINE'].value_counts().plot(kind='bar')

# %%
corr = sales.corr()

corr
# Out:
#                  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# ORDERNUMBER         1.000000         0.065543  -0.002935        -0.055550
# QUANTITYORDERED     0.065543         1.000000   0.005564        -0.018397
# PRICEEACH          -0.002935         0.005564   1.000000        -0.020965
# ORDERLINENUMBER    -0.055550        -0.018397  -0.020965         1.000000
# SALES               0.039919         0.551426   0.657841        -0.058400
# QTR_ID             -0.051383        -0.035323   0.008712         0.040716
# MONTH_ID           -0.039723        -0.039048   0.005152         0.034016
# YEAR_ID             0.904596         0.069535  -0.005938        -0.057367
# MSRP               -0.010280         0.017881   0.670625        -0.021067
#
#                     SALES    QTR_ID  MONTH_ID   YEAR_ID      MSRP
# ORDERNUMBER      0.039919 -0.051383 -0.039723  0.904596 -0.010280
# QUANTITYORDERED  0.551426 -0.035323 -0.039048  0.069535  0.017881
# ...

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x1c6e662a310>,
# ...
#  [Text(0, 0, 'ORDERNUMBER'),
#   Text(0, 0, 'QUANTITYORDERED'),
#   Text(0, 0, 'PRICEEACH'),
#   Text(0, 0, 'ORDERLINENUMBER'),
#   Text(0, 0, 'SALES'),
#   Text(0, 0, 'QTR_ID'),
#   Text(0, 0, 'MONTH_ID'),
#   Text(0, 0, 'YEAR_ID'),
#   Text(0, 0, 'MSRP')])

# %%
sales.plot(kind='scatter', x='QUANTITYORDERED', y='SALES')

# %%
sales.plot(kind='scatter', x='PRICEEACH', y='SALES')

# %%
ax=sales[['SALES', 'PRODUCTLINE']].boxplot(by='PRODUCTLINE',figsize=(15, 12))
ax.set_ylabel('SALES')
# Out:
# Text(0, 0.5, 'SALES')

# %%
boxplot_cols = ['QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER', 'SALES',  'MSRP', 'QTR_ID']

sales[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3),figsize=(14, 8))
# Out:
# QUANTITYORDERED       AxesSubplot(0.125,0.536818;0.227941x0.343182)
# PRICEEACH          AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# ORDERLINENUMBER    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# SALES                    AxesSubplot(0.125,0.125;0.227941x0.343182)
# MSRP                  AxesSubplot(0.398529,0.125;0.227941x0.343182)
# QTR_ID                AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %%
sales['newVar'] = sales['SALES'] / sales['PRICEEACH']

sales['newVar'].head()
# Out:
# 0    30.0000
# 1    34.0000
# 2    41.0000
# 3    45.0000
# 4    52.0527
# Name: newVar, dtype: float64

# %%
sales['newVar'].plot(kind='kde')

# %%
sales.loc[sales['COUNTRY'] == 'Spain', ].head()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 25         10417               66      100.0                2   7516.08
# 28         10126               38      100.0               11   7329.06
# 53         10424               50      100.0                6  12001.00
# 79         10417               45      100.0                5   5887.35
# 105        10417               56      100.0                4   9218.16
#
#      ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 25  2005-05-13    Disputed       2         5     2005  ...          NaN
# 28  2003-05-28     Shipped       2         5     2003  ...          NaN
# 53  2005-05-31  In Process       2         5     2005  ...          NaN
# 79  2005-05-13    Disputed       2         5     2005  ...          NaN
# 105 2005-05-13    Disputed       2         5     2005  ...          NaN
#
#        CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
sales.loc[sales['COUNTRY'] == 'Spain', ].shape[0]
# Out:
# 342

# %%
sales.loc[sales['COUNTRY'] == 'Spain', 'SALES'].mean()
# Out:
# 3554.6401169590667
